# %%
from nes_py.wrappers import JoypadSpace
import retro
import gym

from matplotlib import pyplot as plt
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
import os
from stable_baselines3 import PPO

from stable_baselines3.common.results_plotter import load_results, ts2xy
import numpy as np
from stable_baselines3.common.callbacks import BaseCallback

import cv2
import pandas as pd

CHECK_FREQ_NUMB = 10000
TOTAL_TIMESTEP_NUMB = 2000000
# LEARNING_RATE = 0.00005
LEARNING_RATE = 0.000003
N_STEPS = 2048
GAMMA = 0.99
BATCH_SIZE = 64
N_EPOCHS = 10
DOWN_SAMPLE_RATE = 3
SKIP_NUMB = 4
EPISODE_NUMBERS = 20

CHECKPOINT_DIR = './optuna_training/'
LOG_DIR = './logs/'
REWARD_LOG_FILENAME = 'reward_log.csv'

with open(REWARD_LOG_FILENAME, 'a') as f:
    print('timesteps,reward', file=f)


# 计算奖励函数
class DeadlockEnv(gym.Wrapper):
    def __init__(self, env, threshold=10):
        super().__init__(env)
        self.last_lives = 2
        self.count = 0
        self.threshold = threshold
        self.last_xscroll = 0
        self.score=0

        
    def reset(self, **kwargs):
        self.score=0
        self.last_lives = 2
        self.count = 0
        self.last_xscroll = 0
        return self.env.reset(**kwargs)

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        reward=0
        # self.env.render()
        ifdie=info['die']
        lives = info['lives']
        score =  info['score']
        xpos=info['xpos']
        xscroll=info['xscroll']
        boss_defeated=info['beat_boss']
        # if score>self.score:
        #     reward+=(score-self.score)/100
        # 失去生命减分
        # if lives <self.last_lives:
        #     reward-=3000
        #     self.last_lives=lives
        # 防止卡死
        if xscroll <= self.last_xscroll and xscroll <3072:
            self.count += 1
        else:
            self.count = 0
        if self.count >= 800:
            reward -= 10
            done = True

        if xscroll==self.last_xscroll:
            reward-=0.1
        
        if xpos<=100:
            reward-=0.1

        if ifdie != 1:
            reward-=100
            done=True
        # 3072是管卡最后，136是可以打到敌人的位置
        if xscroll > self.last_xscroll or xscroll ==3072:
            reward+=1
            self.last_xscroll=xscroll
            if xscroll ==3072:
                reward+=136-xpos
            if xpos==136:
                reward+=10

        # if lives ==1:
        #     done=True
        # 通关得分
        if boss_defeated==8:
            reward += 5000
        return state, reward, done, info

# 跳过画面每2真保留一个画面，节省计算时间
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if done:
                break
        return obs, reward, done, info

class Downsample(gym.ObservationWrapper):
    def __init__(self, env, ratio):
        """
        Downsample images by a factor of ratio
        """
        gym.ObservationWrapper.__init__(self, env)
        (oldh, oldw, oldc) = env.observation_space.shape
        newshape = (oldh//ratio, oldw//ratio, oldc)
        self.observation_space = gym.spaces.Box(low=0, high=255,
            shape=newshape, dtype=np.uint8)

    def observation(self, frame):
        height, width, _ = self.observation_space.shape
        frame = cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)
        if frame.ndim == 2:
            frame = frame[:,:,None]
        return frame

class Discretizer(gym.ActionWrapper):
    """
    Wrap a gym environment and make it use discrete actions.
    Args:
        combos: ordered list of lists of valid button combinations
    """

    def __init__(self, env, combos):
        super().__init__(env)
        assert isinstance(env.action_space, gym.spaces.MultiBinary)
        buttons = env.unwrapped.buttons
        self._decode_discrete_action = []
        for combo in combos:
            arr = np.array([False] * env.action_space.n)
            for button in combo:
                arr[buttons.index(button)] = True
            self._decode_discrete_action.append(arr)

        self.action_space = gym.spaces.Discrete(
            len(self._decode_discrete_action))

    def action(self, act):
        return self._decode_discrete_action[act].copy()


class SonicDiscretizer(Discretizer):
    """
    Use Sonic-specific discrete actions
    based on https://github.com/openai/retro-baselines/blob/master/agents/sonic_util.py
    """
    # B是子弹

    def __init__(self, env):
        super().__init__(env=env, combos=[['RIGHT', 'B'],['RIGHT'],['RIGHT', 'A', 'B'], ['B'],['LEFT', 'A', 'B'],['RIGHT', 'UP', 'B']])


class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

            total_reward = [0] * EPISODE_NUMBERS
            total_time = [0] * EPISODE_NUMBERS
            best_reward = 0

            for i in range(EPISODE_NUMBERS):
                state = env.reset()  # reset for each new trial
                done = False
                total_reward[i] = 0
                total_time[i] = 0
                while not done and total_time[i] < 10000:
                    action, _ = model.predict(state)
                    state, reward, done, info = env.step(action)
                    total_reward[i] += reward[0]
                    total_time[i] += 1

                if total_reward[i] > best_reward:
                    best_reward = total_reward[i]
                    best_epoch = self.n_calls

                state = env.reset()  # reset for each new trial

            print('time steps:', self.n_calls, '/', TOTAL_TIMESTEP_NUMB)
            print('average reward:', (sum(total_reward) / EPISODE_NUMBERS),
                  'average time:', (sum(total_time) / EPISODE_NUMBERS),
                  'best_reward:', best_reward,
                  )

            with open(REWARD_LOG_FILENAME, 'a') as f:
                print(self.n_calls, ',', sum(total_reward) / EPISODE_NUMBERS, file=f)

        return True

class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq, save_model_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, 'best_model/')
        self.best_mean_reward = -np.inf

    # def _init_callback(self) -> None:
    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    # def _on_step(self) -> bool:
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ',self.n_calls)
            model_path1 = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path1)
        return True

# ! 设置你要保存模型的位置

# save_model_dir = r'./training/'
# model = PPO("CnnPolicy", env, verbose=1,
#             # tensorboard_log = tensorboard_log,
#             learning_rate = LEARNING_RATE,
#             # device="cuda:0",
#             )
# load model 读取之前训练好的模型
# model.set_parameters("best_model")
# callback1 = SaveOnBestTrainingRewardCallback(10000, save_model_dir)
# model.learn(total_timesteps=1200000,callback=callback1)
# model.save("mario_model")

# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=CHECK_FREQ_NUMB, save_path=CHECKPOINT_DIR)

# %%
import optuna
import copy
from stable_baselines3.common.evaluation import evaluate_policy

# %%
def optimize_ppo(trial): 
    return {
        'n_steps':trial.suggest_int('n_steps', 512, 8192),
        'gamma':trial.suggest_loguniform('gamma', 0.8, 0.9999),
        'learning_rate':trial.suggest_loguniform('learning_rate', 1e-5, 1e-4),
        'clip_range':trial.suggest_uniform('clip_range', 0.1, 0.4),
        'gae_lambda':trial.suggest_uniform('gae_lambda', 0.8, 0.99)
    }

# %%
def optimize_function(trial):
    try:
        env = retro.make(game='Contra-Nes' ,state="Level1")
        # 限制按键
        env = SonicDiscretizer(env)
        # 计算奖励函数
        env = DeadlockEnv(env)
        # 跳过一阵的画面
        env = SkipFrame(env, skip=SKIP_NUMB)
        monitor_dir = r'./monitor_log/'
        os.makedirs(monitor_dir,exist_ok=True)
        env = Monitor(env,monitor_dir)
        env = GrayScaleObservation(env,keep_dim=True)
        # 把画面的画质除以3
        # (224, 240, 1)
        # 变成
        # (74, 80, 1)
        env = Downsample(env, DOWN_SAMPLE_RATE)
        env = DummyVecEnv([lambda: env])
        env = VecFrameStack(env,4,channels_order='last')

        model_params = optimize_ppo(trial) 

        tensorboard_log = r'./tensorboard_log/'
        model = PPO("CnnPolicy", env, verbose=1,tensorboard_log=tensorboard_log,**model_params)
        model.learn(total_timesteps=100000)
    
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=5)

        env.close()
    
        save_model_dir = CHECKPOINT_DIR
        os.makedirs(save_model_dir,exist_ok=True)
        SAVE_PATH = os.path.join(save_model_dir, 'trial_{}_best_model'.format(trial.number))
        model.save(SAVE_PATH)
        return mean_reward    

    except Exception as e:
        print(e)
        return -1000

# %%
study = optuna.create_study(direction='maximize')

study.optimize(optimize_function, n_trials=100)
# Out:
# [I 2023-01-29 00:03:00,906] A new study created in memory with name: no-name-60b8db8a-8936-4e73-9722-94336178848d
# <ipython-input-3-8407fb80ad5e>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 0.8, 0.9999),
# <ipython-input-3-8407fb80ad5e>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate', 1e-5, 1e-4),
# <ipython-input-3-8407fb80ad5e>:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'clip_range':trial.suggest_uniform('clip_range', 0.1, 0.4),
# <ipython-input-3-8407fb80ad5e>:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gae_lambda':trial.suggest_uniform('gae_lambda', 0.8, 0.99)
# c:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:151: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6876`, after every 107 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6876 and n_envs=1)
#   warnings.warn(
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | -32.3    |
# | time/              |          |
# |    fps             | 155      |
# |    iterations      | 1        |
# |    time_elapsed    | 44       |
# |    total_timesteps | 6876     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 2           |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 13752       |
# | train/                  |             |
# |    approx_kl            | 0.038990397 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.000226   |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 4.2         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 3           |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 20628       |
# | train/                  |             |
# |    approx_kl            | 0.029059157 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 9.31        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 91.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 53.2        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 4           |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 27504       |
# | train/                  |             |
# |    approx_kl            | 0.019441398 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 3.76        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 60.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 96.6        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 5           |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 34380       |
# | train/                  |             |
# |    approx_kl            | 0.025658902 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 5.64        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 6           |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 41256       |
# | train/                  |             |
# |    approx_kl            | 0.028053291 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 1.13        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 49.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 331        |
# |    ep_rew_mean          | 171        |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 7          |
# |    time_elapsed         | 625        |
# |    total_timesteps      | 48132      |
# | train/                  |            |
# |    approx_kl            | 0.01371282 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.256      |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.51       |
# |    learning_rate        | 7.08e-05   |
# |    loss                 | 1.59       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00323   |
# |    value_loss           | 43.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 8           |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 55008       |
# | train/                  |             |
# |    approx_kl            | 0.015283664 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 1.56        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 50.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 303        |
# |    ep_rew_mean          | 161        |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 9          |
# |    time_elapsed         | 824        |
# |    total_timesteps      | 61884      |
# | train/                  |            |
# |    approx_kl            | 0.02107931 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.256      |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.325      |
# |    learning_rate        | 7.08e-05   |
# |    loss                 | 6.49       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00249   |
# |    value_loss           | 71.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 10          |
# |    time_elapsed         | 921         |
# |    total_timesteps      | 68760       |
# | train/                  |             |
# |    approx_kl            | 0.012938874 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 39.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 55.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 11          |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 75636       |
# | train/                  |             |
# |    approx_kl            | 0.017681751 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 49.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 12          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 82512       |
# | train/                  |             |
# |    approx_kl            | 0.025116611 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 4.75        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00487     |
# |    value_loss           | 57.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 13          |
# |    time_elapsed         | 1213        |
# |    total_timesteps      | 89388       |
# | train/                  |             |
# |    approx_kl            | 0.021386202 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 3.86        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00746     |
# |    value_loss           | 61.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 14          |
# |    time_elapsed         | 1314        |
# |    total_timesteps      | 96264       |
# | train/                  |             |
# |    approx_kl            | 0.016158847 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 9.16        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00552     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 15          |
# |    time_elapsed         | 1413        |
# |    total_timesteps      | 103140      |
# | train/                  |             |
# |    approx_kl            | 0.016712638 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.256       |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 7.08e-05    |
# |    loss                 | 4.97        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.000676    |
# |    value_loss           | 48.7        |
# -----------------------------------------
# [I 2023-01-29 00:27:33,418] Trial 0 finished with value: -85.3 and parameters: {'n_steps': 6876, 'gamma': 0.8792232977146383, 'learning_rate': 7.075373690819404e-05, 'clip_range': 0.2560519197791735, 'gae_lambda': 0.8563259832121957}. Best is trial 0 with value: -85.3.
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_2
# c:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:151: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5687`, after every 88 untruncated mini-batches, there will be a truncated mini-batch of size 55
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5687 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | -43.1    |
# | time/              |          |
# |    fps             | 179      |
# |    iterations      | 1        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 5687     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 2           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 11374       |
# | train/                  |             |
# |    approx_kl            | 0.031020341 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.000491    |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 9.11        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 216         |
# |    ep_rew_mean          | 24.4        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 3           |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 17061       |
# | train/                  |             |
# |    approx_kl            | 0.024193311 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 10.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 80.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | 36.7        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 4           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 22748       |
# | train/                  |             |
# |    approx_kl            | 0.024044173 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 5.51        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 54.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 80.6        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 5           |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 28435       |
# | train/                  |             |
# |    approx_kl            | 0.012698959 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 14.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 70.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 6            |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 34122        |
# | train/                  |              |
# |    approx_kl            | 0.0144030135 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.227        |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 9.58e-05     |
# |    loss                 | 3.06         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00884     |
# |    value_loss           | 62.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 7           |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 39809       |
# | train/                  |             |
# |    approx_kl            | 0.015410393 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 10.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 49.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 258        |
# |    ep_rew_mean          | 115        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 8          |
# |    time_elapsed         | 581        |
# |    total_timesteps      | 45496      |
# | train/                  |            |
# |    approx_kl            | 0.02027539 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.227      |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.458      |
# |    learning_rate        | 9.58e-05   |
# |    loss                 | 10.6       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00597   |
# |    value_loss           | 68.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 9           |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 51183       |
# | train/                  |             |
# |    approx_kl            | 0.016204147 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 46.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 47.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 282        |
# |    ep_rew_mean          | 135        |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 10         |
# |    time_elapsed         | 739        |
# |    total_timesteps      | 56870      |
# | train/                  |            |
# |    approx_kl            | 0.01963196 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.227      |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.46       |
# |    learning_rate        | 9.58e-05   |
# |    loss                 | 4.65       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00927   |
# |    value_loss           | 56.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 294         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 11          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 62557       |
# | train/                  |             |
# |    approx_kl            | 0.024032183 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 3.04        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 318         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 12          |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 68244       |
# | train/                  |             |
# |    approx_kl            | 0.018828416 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 52.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00145     |
# |    value_loss           | 37.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 13          |
# |    time_elapsed         | 976         |
# |    total_timesteps      | 73931       |
# | train/                  |             |
# |    approx_kl            | 0.024298294 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 2.61        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00578     |
# |    value_loss           | 23.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 14          |
# |    time_elapsed         | 1054        |
# |    total_timesteps      | 79618       |
# | train/                  |             |
# |    approx_kl            | 0.018621493 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 0.727       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00588     |
# |    value_loss           | 55.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 15          |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 85305       |
# | train/                  |             |
# |    approx_kl            | 0.016495435 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 1.21        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.000311    |
# |    value_loss           | 36.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 16          |
# |    time_elapsed         | 1213        |
# |    total_timesteps      | 90992       |
# | train/                  |             |
# |    approx_kl            | 0.019683192 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 2.25        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 35.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 302        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 17         |
# |    time_elapsed         | 1292       |
# |    total_timesteps      | 96679      |
# | train/                  |            |
# |    approx_kl            | 0.02507898 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.227      |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 9.58e-05   |
# |    loss                 | 29         |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00504    |
# |    value_loss           | 44.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 290         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 18          |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 102366      |
# | train/                  |             |
# |    approx_kl            | 0.017427836 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.227       |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 9.58e-05    |
# |    loss                 | 19.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# [I 2023-01-29 00:51:13,460] Trial 1 finished with value: -85.3 and parameters: {'n_steps': 5687, 'gamma': 0.9167480489960909, 'learning_rate': 9.583687078029826e-05, 'clip_range': 0.22662893674725865, 'gae_lambda': 0.8010144581471187}. Best is trial 0 with value: -85.3.
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_3
# c:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:151: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7447`, after every 116 untruncated mini-batches, there will be a truncated mini-batch of size 23
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7447 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -18.7    |
# | time/              |          |
# |    fps             | 178      |
# |    iterations      | 1        |
# |    time_elapsed    | 41       |
# |    total_timesteps | 7447     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 203        |
# |    ep_rew_mean          | 13.3       |
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 2          |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 14894      |
# | train/                  |            |
# |    approx_kl            | 0.13848385 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.375      |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.0011     |
# |    learning_rate        | 8.9e-05    |
# |    loss                 | 194        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0366    |
# |    value_loss           | 75.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 29.4        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 3           |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 22341       |
# | train/                  |             |
# |    approx_kl            | 0.062233914 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 1.92        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 66.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 37.9        |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 4           |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 29788       |
# | train/                  |             |
# |    approx_kl            | 0.030707186 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.0954      |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 4.24        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 68.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 5           |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 37235       |
# | train/                  |             |
# |    approx_kl            | 0.034713916 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 25.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 70.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 166        |
# |    ep_rew_mean          | 30.9       |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 6          |
# |    time_elapsed         | 562        |
# |    total_timesteps      | 44682      |
# | train/                  |            |
# |    approx_kl            | 0.03274046 |
# |    clip_fraction        | 0.0783     |
# |    clip_range           | 0.375      |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.337      |
# |    learning_rate        | 8.9e-05    |
# |    loss                 | 22.7       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 83.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 7           |
# |    time_elapsed         | 667         |
# |    total_timesteps      | 52129       |
# | train/                  |             |
# |    approx_kl            | 0.041998666 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 0.634       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 168         |
# |    ep_rew_mean          | 30.6        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 8           |
# |    time_elapsed         | 771         |
# |    total_timesteps      | 59576       |
# | train/                  |             |
# |    approx_kl            | 0.049957074 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 11.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00746     |
# |    value_loss           | 75.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 46.8        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 9           |
# |    time_elapsed         | 875         |
# |    total_timesteps      | 67023       |
# | train/                  |             |
# |    approx_kl            | 0.037148997 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 2.63        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00241     |
# |    value_loss           | 58.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 10          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 74470       |
# | train/                  |             |
# |    approx_kl            | 0.029641688 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 2.58        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 53.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 11          |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 81917       |
# | train/                  |             |
# |    approx_kl            | 0.017375661 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 0.736       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 74.3        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 12          |
# |    time_elapsed         | 1188        |
# |    total_timesteps      | 89364       |
# | train/                  |             |
# |    approx_kl            | 0.033801623 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 1.5         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 41.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 13          |
# |    time_elapsed         | 1292        |
# |    total_timesteps      | 96811       |
# | train/                  |             |
# |    approx_kl            | 0.024181992 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.375       |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 8.9e-05     |
# |    loss                 | 0.783       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 43          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 235        |
# |    ep_rew_mean          | 85.3       |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 14         |
# |    time_elapsed         | 1396       |
# |    total_timesteps      | 104258     |
# | train/                  |            |
# |    approx_kl            | 0.03052736 |
# |    clip_fraction        | 0.0959     |
# |    clip_range           | 0.375      |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.346      |
# |    learning_rate        | 8.9e-05    |
# |    loss                 | 2.31       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00349   |
# |    value_loss           | 38.4       |
# ----------------------------------------
# [I 2023-01-29 01:15:35,907] Trial 2 finished with value: -8.5 and parameters: {'n_steps': 7447, 'gamma': 0.8023828415178148, 'learning_rate': 8.901664351549502e-05, 'clip_range': 0.37478557574609495, 'gae_lambda': 0.8027517473595028}. Best is trial 2 with value: -8.5.
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_4
# c:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:151: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8090`, after every 126 untruncated mini-batches, there will be a truncated mini-batch of size 26
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=8090 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 165      |
# |    ep_rew_mean     | -37.4    |
# | time/              |          |
# |    fps             | 179      |
# |    iterations      | 1        |
# |    time_elapsed    | 45       |
# |    total_timesteps | 8090     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -33.1       |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 2           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 16180       |
# | train/                  |             |
# |    approx_kl            | 0.007151686 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.141       |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 1.15e-05    |
# |    loss                 | 39.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | -3.65       |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 3           |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 24270       |
# | train/                  |             |
# |    approx_kl            | 0.008616529 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.141       |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 1.15e-05    |
# |    loss                 | 18.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | 25          |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 4           |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 32360       |
# | train/                  |             |
# |    approx_kl            | 0.007416393 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.141       |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 1.15e-05    |
# |    loss                 | 6.84        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 254          |
# |    ep_rew_mean          | 61.2         |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 5            |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 40450        |
# | train/                  |              |
# |    approx_kl            | 0.0066348356 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.141        |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 1.15e-05     |
# |    loss                 | 7.76         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 72           |
# ...
# |    iterations           | 12          |
# |    time_elapsed         | 1243        |
# |    total_timesteps      | 82584       |
# | train/                  |             |
# |    approx_kl            | 0.010921704 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.194       |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 9.01e-05    |
# |    loss                 | 5.74        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000448    |
# |    value_loss           | 40.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 233        |
# |    ep_rew_mean          | 96.6       |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 13         |
# |    time_elapsed         | 1351       |
# |    total_timesteps      | 89466      |
# | train/                  |            |
# |    approx_kl            | 0.01113181 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.194      |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.513      |
# |    learning_rate        | 9.01e-05   |
# |    loss                 | 128        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00283   |
# |    value_loss           | 45.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 98.3        |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 14          |
# |    time_elapsed         | 1461        |
# |    total_timesteps      | 96348       |
# | train/                  |             |
# |    approx_kl            | 0.018342761 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.194       |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 9.01e-05    |
# |    loss                 | 7.42        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 48.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 79.9        |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 15          |
# |    time_elapsed         | 1569        |
# |    total_timesteps      | 103230      |
# | train/                  |             |
# |    approx_kl            | 0.016116435 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.194       |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 9.01e-05    |
# |    loss                 | 5.41        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 50.7        |
# -----------------------------------------
# [I 2023-01-30 16:58:03,031] Trial 98 finished with value: -73.3 and parameters: {'n_steps': 6882, 'gamma': 0.8001516874444216, 'learning_rate': 9.010927176564117e-05, 'clip_range': 0.19364976782472182, 'gae_lambda': 0.8931511898560015}. Best is trial 23 with value: 209.3.
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_100
# c:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:151: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7250`, after every 113 untruncated mini-batches, there will be a truncated mini-batch of size 18
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7250 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | -21.1    |
# | time/              |          |
# |    fps             | 152      |
# |    iterations      | 1        |
# |    time_elapsed    | 47       |
# |    total_timesteps | 7250     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 215        |
# |    ep_rew_mean          | 15.1       |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 2          |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 14500      |
# | train/                  |            |
# |    approx_kl            | 0.09468086 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | 0.000664   |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 110        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0227    |
# |    value_loss           | 90.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 3           |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 21750       |
# | train/                  |             |
# |    approx_kl            | 0.037619416 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 1.54        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 65          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 258        |
# |    ep_rew_mean          | 82.5       |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 4          |
# |    time_elapsed         | 390        |
# |    total_timesteps      | 29000      |
# | train/                  |            |
# |    approx_kl            | 0.04030677 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.129      |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 1.06       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00982   |
# |    value_loss           | 61.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 5           |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 36250       |
# | train/                  |             |
# |    approx_kl            | 0.044187162 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 33          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 60.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 156        |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 6          |
# |    time_elapsed         | 619        |
# |    total_timesteps      | 43500      |
# | train/                  |            |
# |    approx_kl            | 0.02620952 |
# |    clip_fraction        | 0.0912     |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.298      |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 3.81       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00966   |
# |    value_loss           | 43.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 7           |
# |    time_elapsed         | 734         |
# |    total_timesteps      | 50750       |
# | train/                  |             |
# |    approx_kl            | 0.040391102 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 9.62        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 43.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 320        |
# |    ep_rew_mean          | 167        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 8          |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 58000      |
# | train/                  |            |
# |    approx_kl            | 0.04363575 |
# |    clip_fraction        | 0.0918     |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.281      |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 1.39       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00303   |
# |    value_loss           | 51.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 306        |
# |    ep_rew_mean          | 151        |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 9          |
# |    time_elapsed         | 963        |
# |    total_timesteps      | 65250      |
# | train/                  |            |
# |    approx_kl            | 0.07295418 |
# |    clip_fraction        | 0.0957     |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.206      |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 34         |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0155    |
# |    value_loss           | 66.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 10          |
# |    time_elapsed         | 1078        |
# |    total_timesteps      | 72500       |
# | train/                  |             |
# |    approx_kl            | 0.031170346 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 6.38        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00697     |
# |    value_loss           | 54.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 11          |
# |    time_elapsed         | 1193        |
# |    total_timesteps      | 79750       |
# | train/                  |             |
# |    approx_kl            | 0.036056794 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 1.21        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00122     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 12          |
# |    time_elapsed         | 1308        |
# |    total_timesteps      | 87000       |
# | train/                  |             |
# |    approx_kl            | 0.043658663 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 2.23        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 39.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 13          |
# |    time_elapsed         | 1423        |
# |    total_timesteps      | 94250       |
# | train/                  |             |
# |    approx_kl            | 0.030211939 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.376       |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 7.17e-05    |
# |    loss                 | 33          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.000601    |
# |    value_loss           | 48.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 311        |
# |    ep_rew_mean          | 132        |
# | time/                   |            |
# |    fps                  | 65         |
# |    iterations           | 14         |
# |    time_elapsed         | 1539       |
# |    total_timesteps      | 101500     |
# | train/                  |            |
# |    approx_kl            | 0.05475043 |
# |    clip_fraction        | 0.0865     |
# |    clip_range           | 0.376      |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.301      |
# |    learning_rate        | 7.17e-05   |
# |    loss                 | 1.91       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00201    |
# |    value_loss           | 50.1       |
# ----------------------------------------
# [I 2023-01-30 17:24:52,402] Trial 99 finished with value: -72.7 and parameters: {'n_steps': 7250, 'gamma': 0.8265198093736982, 'learning_rate': 7.166424438383656e-05, 'clip_range': 0.37584976197199327, 'gae_lambda': 0.8720125081272557}. Best is trial 23 with value: 209.3.

# %%
study.best_params
# Out:
# {'n_steps': 5976,
#  'gamma': 0.8431945080247621,
#  'learning_rate': 9.434717363652453e-05,
#  'clip_range': 0.366043287552883,
#  'gae_lambda': 0.8177999838257695}

# %%
study.best_trial
# Out:
# FrozenTrial(number=23, values=[209.3], datetime_start=datetime.datetime(2023, 1, 29, 9, 11, 37, 111110), datetime_complete=datetime.datetime(2023, 1, 29, 9, 35, 22, 783561), params={'n_steps': 5976, 'gamma': 0.8431945080247621, 'learning_rate': 9.434717363652453e-05, 'clip_range': 0.366043287552883, 'gae_lambda': 0.8177999838257695}, distributions={'n_steps': IntDistribution(high=8192, log=False, low=512, step=1), 'gamma': FloatDistribution(high=0.9999, log=True, low=0.8, step=None), 'learning_rate': FloatDistribution(high=0.0001, log=True, low=1e-05, step=None), 'clip_range': FloatDistribution(high=0.4, log=False, low=0.1, step=None), 'gae_lambda': FloatDistribution(high=0.99, log=False, low=0.8, step=None)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=23, state=TrialState.COMPLETE, value=None)

# %%
study.trials_dataframe
# Out:
# <bound method Study.trials_dataframe of <optuna.study.study.Study object at 0x000002A367E69B80>>
